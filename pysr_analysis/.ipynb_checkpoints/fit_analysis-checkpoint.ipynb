# %%
#from pysr import PySRRegressor, TemplateExpressionSpec

import matplotlib.pyplot as plt
import numpy as np

import camb

# %%
fid_ombh2 = 0.0224
fid_omch2 = 0.12

# %%
plt.rcParams['font.family'] = 'stixgeneral'

# %%
# Load Data
pars     = np.load('../CL_data/parameter_all.npy')  # [H0, ombh2, omch2 ] x 100
lensed   = np.load('../CL_data/lensed_all.npy')     # [C_2, ..., C_5000] x 100 (lensed)
unlensed = np.load('../CL_data/unlensed_all.npy')     # [C_2, ..., C_5000] x 100 (unlensed)

pars     = np.load('../CL_data/parameter_all_smaller3.npy')  # [H0, ombh2, omch2 ] x 100
lensed   = np.load('../CL_data/lensed_all_smaller3.npy')     # [C_2, ..., C_5000] x 100 (lensed)
unlensed = np.load('../CL_data/unlensed_all_smaller3.npy')     # [C_2, ..., C_5000] x 100 (unlensed)

# %%
ells = np.array([l for l in range(2, 5000)])

# %%
def lensing_tail_fit0(ell, ombh2, omch2, a = 0, ns = 0):
    
    #this is the fit from the paper
    #assuming i haven't typo'd

    ommh2 = ombh2 + omch2
    
    beta_1 = 0.83
    beta_2 = 3218
    beta_3 = 3240
    
    # Sigmoid
    sigm = (1 + np.exp(-(ell-beta_3)/100))**(-1)

    # Exponent
    alpha = (ombh2**-0.877) * (ommh2) - 3.342*(ommh2) - 1.118

    # Polynomial
    poly = (beta_1*(ell/beta_2)**alpha - 1)

    L = poly*sigm + 1
    
    return L  #, poly, sigm

# %%
def lensing_tail_fit1(ell, ombh2, omch2, a, ns):
    x5 = a / 3.043 - 1
    x2 = omch2/0.12 -1
    x1 = ombh2/0.0224 -1
    x6 = ns / 0.965 - 1

        
    beta_1 = 0.6838  * (1 + 0.6785  * x1 + 5.1423 * x1 **2 +-0.0394 * x2 + 1.1529 * x1 * x2  + 0.00295 * x5 + 0.0772 * x5**2 + 0.02447 * x2 * x5 + 0.21970498 * x1 * x5 + -0.45739598 * x1  * x2  * x5  )
    beta_2 = 2803.1562 * (1 + -0.2020 * x1 + -0.1305 * x2 + -0.03670 * x1 ** 2 + 0.1632 * x2 **2 + 0.01521 * x1 * x2 +0.01288  * x5 + -0.1299 * x5**2 + -0.0278 * x2 * x5 )
    
    beta_3 = 3752.098 * (1 + 0.7636 * x1 + -0.4728 * x2  + 0.3576 * x2**2  + 0.5453 * x1**2 + 0.67459829 * x1 * x2 + -0.1017 * x5 + 0.1915  * x5**2 + 1.1921 * x2 * x5 + 0.72633366 * x1 * x5 + 0.01193 * x6 + 0.1114 * x6 **2 + -0.20152526  * x2 * x6 + 0.94373655 * x1 * x2 * x5 + 1.49134297 * x1 * x5 * x6 + -1.71554494 * x2 * x5 * x6 + 9.12155744 * x1 * x2 * x5 * x6)
    beta_4 = 407.009 *  np.abs(1 + 1.4784 * x1 + 0.2269 * x1 **2 + -0.066 * x2 + -0.1976 *x2**2 + -2.74281344 * x1 * x2 + 43.89663989 * x1 **2 * x2 **2 + 0.5307 * x5 + 0.1483 * x5**2 + 1.0168 * x2 * x5 +  5.56638597 * x1 * x5 + 1.3423 * x6 + 1.3534 * x6 **2 + 2.46017622 * x1 * x6 + 13.78584921 * x1 **2 * x6 **2  + -0.57399636 * x2 * x6 + 7.73678052 * x1 *  x2 * x5 + 0.67021089 * x1 * x5 * x6 + 0.77986018 * x2 * x5 * x6 + 11.97190956 * x1 * x2 * x5 * x6)
    alpha =  2.5867 * np.abs(1 + -1.1877 * x1 + 0.700  * x2 +0.2784 * x1 **2  + 0.3064 * x2 **2 + -1.01633878 * x1 * x2 + -0.65334445 * x1 **2 * x2 **2 + 1.4088  * x5 + 0.7482    * x5**2  +1.006 *  x5 * x2 + -1.10231154 * x1 * x5 + -1.52840887 * x1 **2 * x5 **2+ 0.4324  * x6 +0.2114 * x6 **2 + 0.3 * x5 * x6  + 0.4246 * x2 * x6+ 0.0382146 * x1 * x6  + -0.14354912 * x2 * x6 + 0.60365633 * x1 * x2 * x5 + 0.61560613 * x1 * x5 * x6 + -0.18155256 * x2 * x5 * x6 + 2.10418038 * x1 * x2 * x5 * x6)

    sigm = (1 + np.exp(-(ell-beta_3)/beta_4))**(-1)

    poly = (beta_1*(ell/beta_2)**alpha - 1)
    
    L = poly*sigm + 1
    
    return L

# %%
def return_error(func): #H0, ombh2, omch2, a_s, n_s
    return [100*np.abs(func(ells, pars[ind, 1], pars[ind, 2], pars[ind, 3], pars[ind, 4]) - lensed[ind]/unlensed[ind])/(lensed[ind]/unlensed[ind]) for ind in range(len(pars))]

# %%
error0 = return_error(lensing_tail_fit0)
error1 = return_error(lensing_tail_fit1)
# Out:
# /tmp/ipykernel_24445/1082360816.py:15: RuntimeWarning: overflow encountered in exp
#   sigm = (1 + np.exp(-(ell-beta_3)/beta_4))**(-1)

# %%
fig, ax = plt.subplots(1, 1, figsize = (10, 5))
# Fit % Error for 100 Cosmologies
#for ind in range(0, 100):
    #ax.semilogx(ells, error0[ind], "r", label='new fitting formula')
for ind in range(0, 100):
    ax.semilogx(ells, error1[ind], "r", label='new fitting formula')


ax.set_xlim(3000, 5000)
ax.set_xlabel("$\\ell$")

ax.set_ylabel("% error against CAMB lensing tail")


handles, labels = fig.gca().get_legend_handles_labels()
newLabels, newHandles = [], []
for handle, label in zip(handles, labels):
    if label not in newLabels:
        newLabels.append(label)
        newHandles.append(handle)
ax.legend(newHandles, newLabels)

# %%
i = 0
for ind in range(len(pars)):
    err = 100*np.abs(lensing_tail_fit1(ells, pars[ind, 1], pars[ind, 2], pars[ind, 3], pars[ind, 4]) - lensed[ind]/unlensed[ind])/(lensed[ind]/unlensed[ind])
    if np.max(err) > 75:
        if pars[ind][1] > 0.03 or pars[ind][1] < 0.01:
            if pars[ind][2] > 0.21 or pars[ind][2] < 0.06: 
                i += 1
        print(pars[ind])
print(i)
# Out:
# [5.21773281e+01 2.95175090e-02 1.80461876e-01 1.81085595e+00
#  1.14141874e+00]
# [7.87352628e+01 7.85778848e-03 2.15128575e-01 3.44471900e+00
#  9.69020194e-01]
# [7.44737455e+01 7.19480741e-03 2.09350506e-01 3.45894497e+00
#  9.75237845e-01]
# 1
# /tmp/ipykernel_24445/1082360816.py:15: RuntimeWarning: overflow encountered in exp
#   sigm = (1 + np.exp(-(ell-beta_3)/beta_4))**(-1)

# %%
np.mean(error1)
# Out:
# 12.251473058477094

# %%
def pars_of_error(perc):
    inds = []
    for i in range(len(error)):
        if np.mean(error[i]) > perc:
            inds.append(i)
    ombs = []
    omcs = []
    for i in inds:
        ombs.append(pars[i][1])
        omcs.append(pars[i][2])
    return ombs, omcs

# %%
#ombs20, omcs20 = pars_of_error(20)
#ombs10, omcs10 = pars_of_error(10)

fid_ombh2 = 0.0224
fid_omch2 = 0.12

# %%
#plt.scatter(ombs10, omcs10, color = "orange", label = "> 10% error (mean)")
#plt.scatter(ombs20, omcs20, color = "red", label = "> 20% error (mean)")
#plt.scatter(fid_ombh2, fid_omch2, color = "black", label = "Fiducial Cosmology (reference)")
#plt.legend()
#plt.xlabel("$\Omega_bh^2$")
#plt.ylabel("$\Omega_ch^2$")
#plt.show()

# %%
def plot_scatter(error):
    fig,ax = plt.subplots()
    for i in range(len(error)):
        a = ax.scatter(pars[i][1], pars[i][2],s=5, c = np.mean(error[i]), cmap = "Reds", vmax = np.mean(error) + np.std(error), vmin =  np.mean(error) - np.std(error))
    plt.scatter(fid_ombh2, fid_omch2, color = "black", s= 10, marker = "x", label = "Fiducial Cosmology (reference)")
    fig.colorbar(a, ax=ax, label = "Mean % Error")
    plt.xlabel("$\\Omega_bh^2$")
    plt.ylabel("$\\Omega_ch^2$")

# %%
plot_scatter(error1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 plot_scatter(error1)
#
# NameError: name 'error1' is not defined

# %%
def get_lensing_camb(omb, omc):
    pars = camb.set_params(H0 = 67.4, ombh2 = omb, omch2 = omc, lmax=5000)
    results = camb.get_results(pars)
    powers = results.get_cmb_power_spectra(pars, CMB_unit='muK')
    lensed = powers['total'][2:5000, 0]
    unlensed = powers['unlensed_total'][2:5000, 0]
    return lensed/unlensed

# %%
ombs = [0.022, 0.022, 0.022, 0.022, 0.022, 0.022, 0.022, 0.022]
omcs = [0.07, 0.1, 0.12, 0.15, 0.18, 0.19, 0.21, 0.23]
n = len(omcs)
lensings_camb = [get_lensing_camb(ombs[i], omcs[i]) for i in range(n)]

# %%
lensings_fit = [lensing_tail_fit1(ells, ombs[i], omcs[i], 3.043, 0.965) for i in range(n)]

# %%
#color_key = ["gold","darkmagenta", "pink", "darkgreen", "aqua", "slateblue", "palegreen", "crimson", "blue", "lime"]
color_key = ["brown","gold","darkmagenta", "pink", "darkgreen", "aqua", "slateblue", "palegreen", "crimson", "blue", "lime", "black", "cyan", "lightcoral"]
label_key = ["$\\Omega_bh^2$ = " + str(ombs[i]) + ", $\\Omega_ch^2$ = " + str(omcs[i]) for i in range(n)]
for i in range(n):
    plt.plot(ells, lensings_fit[i], color = color_key[i], linestyle = "--")
    plt.plot(ells, lensings_camb[i], color = color_key[i], label = label_key[i])
plt.plot(0,0, color = "black", label = "CAMB Data")
plt.plot(0,0, color = "black", linestyle = "dashed", label = "Fit")
#plt.ylim(0.7, 10)
plt.xlabel("$\\ell$")
plt.ylabel("Lensing Tail")
plt.legend()
