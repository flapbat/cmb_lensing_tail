# %%
#from pysr import PySRRegressor, TemplateExpressionSpec

import matplotlib.pyplot as plt
import numpy as np

import camb

# %%
fid_ombh2 = 0.0224
fid_omch2 = 0.12

# %%
plt.rcParams['font.family'] = 'stixgeneral'

# %%
# Load Data
pars     = np.load('../CL_data/parameter_all_smaller2.npy')  # [H0, ombh2, omch2 ] x 100
lensed   = np.load('../CL_data/lensed_all_smaller2.npy')     # [C_2, ..., C_5000] x 100 (lensed)
unlensed = np.load('../CL_data/unlensed__all_smaller2.npy')     # [C_2, ..., C_5000] x 100 (unlensed)

# %%
ells = np.array([l for l in range(2, 5000)])

# %%
def lensing_tail_fit0(ell, ombh2, omch2, a = 0, ns = 0):
    
    #this is the fit from the paper
    #assuming i haven't typo'd

    ommh2 = ombh2 + omch2
    
    beta_1 = 0.83
    beta_2 = 3218
    beta_3 = 3240
    
    # Sigmoid
    sigm = (1 + np.exp(-(ell-beta_3)/100))**(-1)

    # Exponent
    alpha = (ombh2**-0.877) * (ommh2) - 3.342*(ommh2) - 1.118

    # Polynomial
    poly = (beta_1*(ell/beta_2)**alpha - 1)

    L = poly*sigm + 1
    
    return L  #, poly, sigm

# %%
def lensing_tail_fit1(ell, ombh2, omch2, a, ns):
    x5 = a / 3.043 - 1
    x2 = omch2/fid_omch2 -1
    x1 = ombh2/fid_ombh2 -1
    x6 = ns / 0.965 - 1
        
    x1b = 1/(x1 + 0.6429) * x1 * x2**2
        
    beta_1 = 0.6838 * (1 + 0.6785  * x1 + 5.1423 * x1 **2 +-0.0394 * x2 + 1.1529 * x1 * x2  + 0.00295 * x5 + 0.0772 * x5**2 + 0.02447 * x2 * x5 + 0.21970498 * x1 * x5 )
    beta_2 = 2803.1562 * (1 + -0.2020 * x1 + -0.1305 * x2 + -0.03670 * x1 ** 2 + 0.1632 * x2 **2 + 0.01521 * x1 * x2 +0.01288  * x5 + -0.1299 * x5**2 + -0.0278 * x2 * x5 + -0.00859838 * x6)
    
    beta_3 = 3752.098 * (1 +  0.00085966 * x1b +  0.7636 * x1 + -0.4728 * x2  + 0.3576 * x2**2  + 0.5453 * x1**2 + 0.43684525 * x1 * x2 + 0.09557926 * x1 **2 * x2  + -0.1017 * x5 + 0.1915  * x5**2 + 1.1921 * x2 * x5 + 0.72633366 * x1 * x5 + 0.01193 * x6 + 0.1114 * x6 **2 + -0.20152526  * x2 * x6 + 0.94373655 * x1 * x2 * x5 + 1.0158203 * x1 * x5 * x6 + -1.69506326 * x2 * x5 * x6 + 9.12155744 * x1 * x2 * x5 * x6)
    beta_4 = 407.009 * np.abs(1 + 0.00087662 * x1b +  1.4784 * x1 + 0.2269 * x1 **2 + -0.066 * x2 + -0.1976 *x2**2 + 2.44643455 * x1 * x2 + -22.58535206 * x1 **2 * x2 **2 + 0.5307 * x5 + 0.1483 * x5**2 + 1.0168 * x2 * x5 +  5.56638597 * x1 * x5 + 1.3423 * x6 + 1.3534 * x6 **2 + 2.46017622 * x1 * x6 + 13.78584921 * x1 **2 * x6 **2  + -0.57399636 * x2 * x6 + 7.73679566 * x1 *  x2 * x5 + 0.67353606 * x1 * x5 * x6 + -1.21380304 * x2 * x5 * x6 + 37.99771398 * x1 * x2 * x5 * x6 + 43.14170145 * x1 * x2 * x5**2 * x6 )
    alpha =   2.5867 * np.abs(1 +0.00007  *  x1b + -1.1877 * x1 + 0.700  * x2 +0.2784 * x1 **2  + 0.2064 * x2 **2 + -1.01633878 * x1 * x2 + -0.65334445 * x1 **2 * x2 **2 + 1.4088  * x5 + 0.7482    * x5**2  +1.006 *  x5 * x2 + -1.10231154 * x1 * x5 + -1.52840887 * x1 **2 * x5 **2+ 0.4324  * x6 +0.2114 * x6 **2 + 0.3 * x5 * x6  + 0.4246 * x2 * x6+ 0.0382146 * x1 * x6  + -0.14354912 * x2 * x6 + 0.37728709 * x1 * x2 * x5 + 0.60171565 * x1 * x5 * x6 + -0.20929162 * x2 * x5 * x6 + 2.05009932 * x1 * x2 * x5 * x6 + -0.10939012 * x1 * x2 * x5**2 * x6 + 7.99534421 * x1 **2 * x2 **2 * x6 **2 * x5 **2)
            
    sigm = (1 + np.exp(-(ell-beta_3)/beta_4))**(-1)

    poly = (beta_1*(ell/beta_2)**alpha - 1)
    
    L = poly*sigm + 1
    #L[0:1000] = 1
    
    return L

# %%
def return_error(func): #H0, ombh2, omch2, a_s, n_s
    return [100*np.abs(func(ells, pars[ind, 1], pars[ind, 2], pars[ind, 3], pars[ind, 4]) - lensed[ind]/unlensed[ind])/(lensed[ind]/unlensed[ind]) for ind in range(len(pars))]

# %%
error0 = return_error(lensing_tail_fit0)
error1 = return_error(lensing_tail_fit1)
# Out:
# /tmp/ipykernel_19874/533121055.py:16: RuntimeWarning: overflow encountered in exp
#   sigm = (1 + np.exp(-(ell-beta_3)/beta_4))**(-1)

# %%
fig, ax = plt.subplots(1, 2, figsize = (10, 5))
# Fit % Error for 100 Cosmologies
for ind in range(0, 100):
    ax[0].semilogx(ells, error0[ind], "r", label='new fitting formula')
for ind in range(0, 100):
    ax[1].semilogx(ells, error1[ind], "r", label='new fitting formula')


for i in range(2):
    ax[i].set_xlim(3000, 5000)
    ax[i].set_xlabel("$\\ell$")

ax[0].set_ylabel("% error against CAMB lensing tail")


handles, labels = fig.gca().get_legend_handles_labels()
newLabels, newHandles = [], []
for handle, label in zip(handles, labels):
    if label not in newLabels:
        newLabels.append(label)
        newHandles.append(handle)
ax[0].legend(newHandles, newLabels)

# %%
i = 0
for ind in range(len(pars)):
    err = 100*np.abs(lensing_tail_fit1(ells, pars[ind, 1], pars[ind, 2], pars[ind, 3], pars[ind, 4]) - lensed[ind]/unlensed[ind])/(lensed[ind]/unlensed[ind])
    if np.max(err) > 80: 
        print(pars[ind])
        i += 1
print(i)
# Out:
# [7.92235812e+01 8.09720125e-03 2.26652707e-01 3.26891275e+00
#  8.58856869e-01]
# [7.19042927e+01 1.43582234e-02 5.13251973e-02 3.21950730e+00
#  7.05720551e-01]
# [7.40776001e+01 3.14181851e-02 1.79257129e-01 2.15127460e+00
#  9.80179337e-01]
# [6.88680677e+01 7.45322368e-03 2.02038168e-01 2.58125083e+00
#  9.96739360e-01]
# [7.46403527e+01 2.19554994e-02 2.29072235e-01 1.80680734e+00
#  7.69022575e-01]
# [5.99124788e+01 3.14251917e-02 1.86849433e-01 2.05433091e+00
#  1.09649412e+00]
# [7.06131073e+01 1.74283431e-02 1.97566684e-01 2.22835497e+00
#  8.84637425e-01]
# [5.86002182e+01 2.94838465e-02 1.92449840e-01 2.24866730e+00
#  9.22610416e-01]
# [7.79961162e+01 1.85516933e-02 2.16505717e-01 2.00966521e+00
#  9.55216924e-01]
# [5.32134764e+01 1.76513247e-02 2.09008237e-01 2.26056456e+00
#  1.01878284e+00]
# [5.70849404e+01 1.89834629e-02 2.12317781e-01 2.38120183e+00
#  7.48722807e-01]
# [6.93579232e+01 1.72521785e-02 2.29915929e-01 1.75908080e+00
#  7.18839393e-01]
# [7.41676932e+01 7.45230586e-03 2.09567065e-01 1.62985493e+00
#  1.01676632e+00]
# [5.37402941e+01 1.80915063e-02 2.27533032e-01 1.86787320e+00
#  9.00305753e-01]
# 14
# /tmp/ipykernel_19874/533121055.py:16: RuntimeWarning: overflow encountered in exp
#   sigm = (1 + np.exp(-(ell-beta_3)/beta_4))**(-1)

# %%
np.max(error1)
# Out:
# 89.3799421643719

# %%
def pars_of_error(perc):
    inds = []
    for i in range(len(error)):
        if np.mean(error[i]) > perc:
            inds.append(i)
    ombs = []
    omcs = []
    for i in inds:
        ombs.append(pars[i][1])
        omcs.append(pars[i][2])
    return ombs, omcs

# %%
#ombs20, omcs20 = pars_of_error(20)
#ombs10, omcs10 = pars_of_error(10)

fid_ombh2 = 0.0224
fid_omch2 = 0.12

# %%
#plt.scatter(ombs10, omcs10, color = "orange", label = "> 10% error (mean)")
#plt.scatter(ombs20, omcs20, color = "red", label = "> 20% error (mean)")
#plt.scatter(fid_ombh2, fid_omch2, color = "black", label = "Fiducial Cosmology (reference)")
#plt.legend()
#plt.xlabel("$\Omega_bh^2$")
#plt.ylabel("$\Omega_ch^2$")
#plt.show()

# %%
def plot_scatter(error):
    fig,ax = plt.subplots()
    for i in range(len(error)):
        a = ax.scatter(pars[i][1], pars[i][2],s=5, c = np.mean(error[i]), cmap = "Reds", vmax = np.mean(error) + np.std(error), vmin =  np.mean(error) - np.std(error))
    plt.scatter(fid_ombh2, fid_omch2, color = "black", s= 10, marker = "x", label = "Fiducial Cosmology (reference)")
    fig.colorbar(a, ax=ax, label = "Mean % Error")
    plt.xlabel("$\Omega_bh^2$")
    plt.ylabel("$\Omega_ch^2$")
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\O'
# <>:8: SyntaxWarning: invalid escape sequence '\O'
# <>:7: SyntaxWarning: invalid escape sequence '\O'
# <>:8: SyntaxWarning: invalid escape sequence '\O'
# /tmp/ipykernel_19874/903577046.py:7: SyntaxWarning: invalid escape sequence '\O'
#   plt.xlabel("$\Omega_bh^2$")
# /tmp/ipykernel_19874/903577046.py:8: SyntaxWarning: invalid escape sequence '\O'
#   plt.ylabel("$\Omega_ch^2$")

# %%
plot_scatter(error1)

# %%
def get_lensing_camb(omb, omc):
    pars = camb.set_params(H0 = 67.4, ombh2 = omb, omch2 = omc, lmax=5000)
    results = camb.get_results(pars)
    powers = results.get_cmb_power_spectra(pars, CMB_unit='muK')
    lensed = powers['total'][2:5000, 0]
    unlensed = powers['unlensed_total'][2:5000, 0]
    return lensed/unlensed

# %%
ombs = [0.022, 0.022, 0.022, 0.022, 0.022, 0.022, 0.022, 0.022]
omcs = [0.07, 0.1, 0.12, 0.15, 0.18, 0.19, 0.21, 0.23]
n = len(omcs)
lensings_camb = [get_lensing_camb(ombs[i], omcs[i]) for i in range(n)]

# %%
lensings_fit = [lensing_tail_fit1(ells, ombs[i], omcs[i], 3.043, 0.965) for i in range(n)]

# %%
color_key = ["gold","darkmagenta", "pink", "darkgreen", "aqua", "slateblue", "palegreen", "crimson", "blue", "lime"]
label_key = ["$\\Omega_bh^2$ = " + str(ombs[i]) + ", $\\Omega_ch^2$ = " + str(omcs[i]) for i in range(n)]
for i in range(n):
    plt.plot(ells, lensings_fit[i], color = color_key[i], linestyle = "--")
    plt.plot(ells, lensings_camb[i], color = color_key[i], label = label_key[i])
plt.xlabel("$\\ell$")
plt.ylabel("Lensing Tail")
plt.legend()
