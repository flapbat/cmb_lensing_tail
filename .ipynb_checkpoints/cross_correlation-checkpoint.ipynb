# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'stixgeneral'
import numpy as np

import camb

# %%
lm = 5000

# %%
def get_lensing_camb(_ombh2, _omch2, _As, _ns):
    #As=np.exp(_As)/(1e10), ns = _ns,
    pars = camb.set_params(ombh2 = _ombh2, omch2 = _omch2, H0 = 67.4, As=np.exp(_As)/(1e10), ns = _ns, lmax=lm)
    results = camb.get_results(pars)
    powers = results.get_cmb_power_spectra(pars, CMB_unit='muK')
    lensed = powers['total'][2:lm, 0]
    unlensed = powers['unlensed_total'][2:lm, 0]
    return lensed/unlensed

# %%
#ns behavior
_ns = [0.5,0.7, 0.9, 1.1, 1.3]
_as =  [3.043 for i in range(len(_ns))]
_omcs = [0.12 for i in range(len(_as))]
_ombs = [0.0224 for i in range(len(_as))]

_as = [ 2.5, 3.5,2.5, 3.5,  2.5, 3.5, 2.5, 3.5]
_ombs = [0.01,0.01,0.01,0.01,0.03,0.03,0.03, 0.03]
_omcs = [0.12,0.12, 0.12, 0.12, 0.12, 0.12, 0.12, 0.12]
_ns = [0.8, 0.8, 1.2, 1.2, 0.8, 0.8, 1.2, 1.2]

#ombs versus ns
_as = [3.043 for i in range(len(_as))]
_ombs = [0.01, 0.01, 0.01, 0.02, 0.02, 0.02, 0.03, 0.03, 0.03]
_omcs = [0.12 for i in range(len(_as))]
_ns = [0.5,0.9,1.3,0.5,0.9,1.3,0.5,0.9,1.3]

#omcs versus ns
_as = [3.043 for i in range(len(_as))]
_ombs = [0.0224 for i in range(len(_as))]
_omcs = [0.07, 0.07, 0.07, 0.15, 0.15, 0.15, 0.23, 0.23, 0.23]
_ns = [0.5,0.9,1.3,0.5,0.9,1.3,0.5,0.9,1.3]

#as versus ns
_as = [ 1.2, 1.2,1.2,2.7,2.7,2.7, 3.8, 3.8, 3.8]
_ombs = [0.0224 for i in range(len(_as))]
_omcs = [0.12 for i in range(len(_as))]
_ns = [0.5,0.9,1.3,0.5,0.9,1.3,0.5,0.9,1.3]

#ns versus ombs
_ombs = [0.007,0.007,0.007, 0.015,0.015,0.015, 0.03, 0.03, 0.03]
_as = [ 2.5,3.5,2.5,3.5,2.5,3.5]
_omcs = [0.12 for i in range(len(_as))]
_ns = [0.965 for i in range(len(_as))]

#ombs versus omcs
_ombs = [0.0224, 0.008, 0.008, 0.008, 0.008]
_omcs = [ 0.12, 0.09, 0.12, 0.15, 0.2]
#_ombs = [0.015, 0.015, 0.015, 0.03, 0.03, 0.03]
#_omcs = [0.09, 0.12, 0.15, 0.09, 0.12, 0.15]
_ns = [0.965 for i in range(len(_omcs))]
_as = [3.043 for i in range(len(_ns))]

#as versus omcs
_as = [ 2.5,3.5,2.5,3.5,2.5,3.5]
_ombs = [0.0224 for i in range(len(_as))]
_omcs = [0.07, 0.07, 0.1, 0.1, 0.17, 0.16]
_ns = [0.965 for i in range(len(_as))]

#testing behavior
_as = [3.043, 1.81085595e+00, 3.44471900, 3.45894497]
_ombs = [0.0224, 2.95175090e-02 ,  7.85778848e-03, 7.19480741e-03 ]
_omcs = [0.12,1.80461876e-01 , 2.15128575e-01, 2.09350506e-01]
_ns =  [0.965 ,  8.58856869e-01, 7.69022575e-01, 1.07214578]

#ombs versus omcs
_ombs = [0.0224, 0.008, 0.008, 0.008, 0.008]
_omcs = [ 0.12, 0.09, 0.12, 0.15, 0.23]
_ombs = [0.015, 0.015, 0.015, 0.03, 0.03, 0.03]
_omcs = [0.09, 0.12, 0.15, 0.09, 0.12, 0.15]
_ns = [0.965 for i in range(len(_omcs))]
_as = [3.043 for i in range(len(_ns))]

#the omcs
_ombs = [0.022, 0.022, 0.022, 0.022, 0.022, 0.022, 0.022, 0.022]
_omcs = [0.07, 0.1, 0.12, 0.15, 0.18, 0.19, 0.21, 0.23]
_ns = [0.965 for i in range(len(_omcs))]
_as = [3.043 for i in range(len(_ns))]

#ombs versus omcs
_ombs = [0.0224, 0.008, 0.008, 0.008, 0.008]
_omcs = [ 0.12, 0.09, 0.12, 0.15, 0.23]
_ombs = [0.015, 0.015, 0.015, 0.03, 0.03, 0.03]
_omcs = [0.09, 0.12, 0.15, 0.09, 0.12, 0.15]
_ns = [0.965 for i in range(len(_omcs))]
_as = [3.043 for i in range(len(_ns))]



ells = np.array([l for l in range(2, lm)])
n = len(_as)
lensings_camb = [get_lensing_camb(_ombs[i], _omcs[i],_as[i], _ns[i]) for i in range(n)]
label_key = ["$a$ = " + str(_as[i]) + ", $\\Omega_bh^2$ = " + str(_ombs[i]) + ", $\\Omega_ch^2$ = " + str(_omcs[i]) + ", $n_s$ = " + str(_ns[i]) for i in range(n)]
fid_ombh2 = 0.0224
fid_omch2 = 0.12

# %%
def lensing_tail_fit1(ell, ombh2, omch2, a, ns):
    x5 = a / 3.043 - 1
    x2 = omch2/0.12 -1
    x1 = ombh2/0.0224 -1
    x6 = ns / 0.965 - 1

        
    beta_1 = 0.6838  * (1 + 0.6785  * x1 + 5.1423 * x1 **2 +-0.0394 * x2 + 1.1529 * x1 * x2  + 0.00295 * x5 + 0.0772 * x5**2 + 0.02447 * x2 * x5 + 0.21970498 * x1 * x5 + -0.45739598 * x1  * x2  * x5  )
    beta_2 = 2803.1562 * (1 + -0.2020 * x1 + -0.1305 * x2 + -0.03670 * x1 ** 2 + 0.1632 * x2 **2 + 0.01521 * x1 * x2 +0.01288  * x5 + -0.1299 * x5**2 + -0.0278 * x2 * x5 )
    
    beta_3 = 3752.098 * (1 + 0.7636 * x1 + -0.4728 * x2  + 0.3576 * x2**2  + 0.5453 * x1**2 + 0.67459829 * x1 * x2 + -0.1017 * x5 + 0.1915  * x5**2 + 1.1921 * x2 * x5 + 0.72633366 * x1 * x5 + 0.01193 * x6 + 0.1114 * x6 **2 + -0.20152526  * x2 * x6 + 0.94373655 * x1 * x2 * x5 + 1.49134297 * x1 * x5 * x6 + -1.71554494 * x2 * x5 * x6 + 9.12155744 * x1 * x2 * x5 * x6)
    beta_4 = 407.009 *  np.abs(1 + 1.4784 * x1 + 0.2269 * x1 **2 + -0.066 * x2 + -0.1976 *x2**2 + -2.74281344 * x1 * x2 + 43.89663989 * x1 **2 * x2 **2 + 0.5307 * x5 + 0.1483 * x5**2 + 1.0168 * x2 * x5 +  5.56638597 * x1 * x5 + 1.3423 * x6 + 1.3534 * x6 **2 + 2.46017622 * x1 * x6 + 13.78584921 * x1 **2 * x6 **2  + -0.57399636 * x2 * x6 + 7.73678052 * x1 *  x2 * x5 + 0.67021089 * x1 * x5 * x6 + 0.77986018 * x2 * x5 * x6 + 11.97190956 * x1 * x2 * x5 * x6)
    alpha =  2.5867 * np.abs(1 + -1.1877 * x1 + 0.700  * x2 +0.2784 * x1 **2  + 0.3064 * x2 **2 + -1.01633878 * x1 * x2 + -0.65334445 * x1 **2 * x2 **2 + 1.4088  * x5 + 0.7482    * x5**2  +1.006 *  x5 * x2 + -1.10231154 * x1 * x5 + -1.52840887 * x1 **2 * x5 **2+ 0.4324  * x6 +0.2114 * x6 **2 + 0.3 * x5 * x6  + 0.4246 * x2 * x6+ 0.0382146 * x1 * x6  + -0.14354912 * x2 * x6 + 0.60365633 * x1 * x2 * x5 + 0.61560613 * x1 * x5 * x6 + -0.18155256 * x2 * x5 * x6 + 2.10418038 * x1 * x2 * x5 * x6)

    sigm = (1 + np.exp(-(ell-beta_3)/beta_4))**(-1)

    poly = (beta_1*(ell/beta_2)**alpha - 1)
    
    L = poly*sigm + 1
    
    return L

# %%
lensings_fit = [lensing_tail_fit1(ells, _ombs[i], _omcs[i],_as[i], _ns[i]) for i in range(n)]

# %%
color_key = ["brown","gold","darkmagenta", "pink", "darkgreen", "aqua", "slateblue", "palegreen", "crimson", "blue", "lime", "black", "cyan", "lightcoral"]
for i in range(n):
    plt.plot(ells, lensings_fit[i], color = color_key[i], linestyle = "dashed", alpha = 0.75)
    plt.plot(ells, lensings_camb[i],  color = color_key[i], label = label_key[i], alpha = 0.75)
plt.plot(0,0, color = "black", label = "CAMB Data")
plt.plot(0,0, color = "black", linestyle = "dashed", label = "Fit")
plt.xlabel("$\\ell$")
plt.ylabel("Lensing Tail")
plt.ylim(0.5,10)
plt.legend()
plt.tight_layout()
plt.savefig("omc_omb.pdf")
plt.show()

for i in [1]: 
    #plt.ylim(0,3)
    plt.plot(ells, lensings_fit[i], color = color_key[i], linestyle = "dashed", alpha = 0.75)
    plt.plot(ells, lensings_camb[i], color = color_key[i], label = label_key[i], alpha = 0.75)
plt.legend()
plt.xlabel("$\\ell$")
plt.ylabel("Lensing Tail")
plt.show()

# %%
omb=0.03
omc=0.12
ns=1
As=3.8

d=lensing_tail_fit1(ells,omb,omc,As,ns)
plt.plot(d)

# %%
lensings_fit = [lensing_tail_fit1(ells, _ombs[i], _omcs[i],_as[i], _ns[i]) for i in range(n)]
#plt.plot(ells, lensings_fit[-1], color = color_key[i], linestyle = "dashed", alpha = 0.75)
#plt.plot(ells, lensings_camb[-1], color = color_key[i], label = label_key[i], alpha = 0.75)
#plt.ylim(0, 3)
