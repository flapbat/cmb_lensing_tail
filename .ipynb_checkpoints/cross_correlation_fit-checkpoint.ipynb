# %%
import matplotlib.pyplot as plt
import numpy as np

import camb

from scipy.optimize import curve_fit

# %%
# Load Data
pars     = np.load('CL_data/parameter_all_smaller3.npy')  # [H0, ombh2, omch2 ] x 100
lensed   = np.load('CL_data/lensed_all_smaller3.npy')     # [C_2, ..., C_5000] x 100 (lensed)
unlensed = np.load('CL_data/unlensed_all_smaller3.npy')     # [C_2, ..., C_5000] x 100 (unlensed)

# %%
ombs = pars[:,1]
omcs = pars[:,2]
As = pars[:,3]
ns = pars[:,4]


ells = np.array([l for l in range(2, 5000)])

# %%
np.min(As)
# Out:
# 1.2037661973802547

# %%
#getting dependent variables
lensing = lensed/unlensed #lensing tail
camb_data_format = []
for i in range(len(lensing)):
    for j in range(len(lensing[i])):
        camb_data_format.append(lensing[i][j])

# %%
fid_ombh2 = 0.0224
fid_omch2 = 0.12

# %%
def func(X, b1):
    #expected form of the lensing tail function for curve fitting
    ell = X[0]
    x2 = (X[1]/0.12) - 1
    x1 = X[2]/ 0.0224 - 1
    x5 = X[3] / 3.043 - 1
    x6 = X[4] / 0.965 - 1 
                 
    beta_1 = 0.6838  * (1 + 0.6785  * x1 + 5.1423 * x1 **2 +-0.0394 * x2 + 1.1529 * x1 * x2  + 0.00295 * x5 + 0.0772 * x5**2 + 0.02447 * x2 * x5 + 0.21970498 * x1 * x5 + -0.45739598 * x1  * x2  * x5   )
    beta_2 = 2803.1562 * (1 + -0.2020 * x1 + -0.1305 * x2 + -0.03670 * x1 ** 2 + 0.1632 * x2 **2 + 0.01521 * x1 * x2 +0.01288  * x5 + -0.1299 * x5**2 + -0.0278 * x2 * x5 )
    
    beta_3 = 3752.098 * (1 + 0.7636 * x1 + -0.4728 * x2  + 0.3576 * x2**2  + 0.5453 * x1**2 + 0.67459829 * x1 * x2 + -0.1017 * x5 + 0.1915  * x5**2 + 1.1921 * x2 * x5 + 0.72633366 * x1 * x5 + 0.01193 * x6 + 0.1114 * x6 **2 + -0.20152526  * x2 * x6 + 0.94373655 * x1 * x2 * x5 + 1.49134297 * x1 * x5 * x6 + -1.71554494 * x2 * x5 * x6 + 9.12155744 * x1 * x2 * x5 * x6)
    beta_4 = 407.009 *  np.abs(1 + 1.4784 * x1 + 0.2269 * x1 **2 + -0.066 * x2 + -0.1976 *x2**2 + -2.74281344 * x1 * x2 + 43.89663989 * x1 **2 * x2 **2 + 0.5307 * x5 + 0.1483 * x5**2 + 1.0168 * x2 * x5 +  5.56638597 * x1 * x5 + 1.3423 * x6 + 1.3534 * x6 **2 + 2.46017622 * x1 * x6 + 13.78584921 * x1 **2 * x6 **2  + -0.57399636 * x2 * x6 + 7.73678052 * x1 *  x2 * x5 + 0.67021089 * x1 * x5 * x6 + 0.77986018 * x2 * x5 * x6 + 11.97190956 * x1 * x2 * x5 * x6)
    alpha =  2.5867 * np.abs(1 + -1.1877 * x1 + 0.700  * x2 +0.2784 * x1 **2  + 0.3064 * x2 **2 + -1.01633878 * x1 * x2 + -0.65334445 * x1 **2 * x2 **2 + 1.4088  * x5 + 0.7482    * x5**2  +1.006 *  x5 * x2 + -1.10231154 * x1 * x5 + -1.52840887 * x1 **2 * x5 **2+ 0.4324  * x6 +0.2114 * x6 **2 + 0.3 * x5 * x6  + 0.4246 * x2 * x6+ 0.0382146 * x1 * x6  + -0.14354912 * x2 * x6 + 0.60365633 * x1 * x2 * x5 + 0.61560613 * x1 * x5 * x6 + -0.18155256 * x2 * x5 * x6 + 2.10418038 * x1 * x2 * x5 * x6  + 0.02 * x1b * x1 * x2)
            
    sigm = (1 + np.exp(-(ell-beta_3)/beta_4))**(-1)

    poly = (beta_1*(ell/beta_2)**alpha - 1)
    
    L = poly*sigm + 1
    #L[0:2000] = 1
    
    return L

# %%
cosmos = [ombs[i] + omcs[i] for i in range(len(ombs))]    #x3 variable
n = len(cosmos) #number of cosmologies
params = np.zeros((len(ells) * n, 5))   #ind variables
for i in range(n):
    params[(i)*len(ells):(i+1)*len(ells),0] = ells
for i in range(n):
    params[(i)*len(ells):(i+1)*len(ells),1] = omcs[i]  #omch2
for i in range(n):
    params[(i)*len(ells):(i+1)*len(ells),2] = ombs[i]  #ombh2
for i in range(n):
    params[(i) * len(ells): (i+1)*len(ells),3] = As[i]
for i in range(n):
    params[(i) * len(ells): (i+1)*len(ells),4] = ns[i]

# %%
p0 = 0

# %%
answers, _ = curve_fit(func,(params[:,0], params[:,1], params[:,2], params[:,3], params[:,4]),camb_data_format, p0)  #doing the curve fitting
# Out:
# /tmp/ipykernel_3585/1782252537.py:18: RuntimeWarning: overflow encountered in exp
#   sigm = (1 + np.exp(-(ell-beta_3)/beta_4))**(-1)

# %%
answers
# Out:
# array([-4.62624637e-06])
