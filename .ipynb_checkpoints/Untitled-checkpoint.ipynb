# %%
import matplotlib.pyplot as plt
import numpy as np

import camb

from scipy.optimize import curve_fit

# %%
# Load Data
pars     = np.load('CL_data/parameter_all.npy')  # [H0, ombh2, omch2 ] x 100
lensed   = np.load('CL_data/lensed_all.npy')     # [C_2, ..., C_5000] x 100 (lensed)
unlensed = np.load('CL_data/unlensed_all.npy')     # [C_2, ..., C_5000] x 100 (unlensed)

# %%
ombs = pars[:,1]
omcs = pars[:,2]
As = pars[:,3] # this is a not A
ns = pars[:,4]


ells = np.array([l for l in range(2, 5000)])

# %%
def lensing_tail_fit(ell, ombh2, omch2, a, ns):
    x5 = a / 3.043 - 1
    x2 = omch2/fid_omch2 -1
    x1 = ombh2/fid_ombh2 -1
    x6 = ns / 0.965 - 1
        
    beta_1 = 0.6838  * (1 + 0.6785  * x1 + 5.1423 * x1 **2 +-0.0394 * x2 + 1.1529 * x1 * x2  + 0.00295 * x5 + 0.0772 * x5**2 + 0.02447 * x2 * x5 + 0.21970498 * x1 * x5)
    beta_2 = 2803.1562 * (1 + -0.2020 * x1 + -0.1305 * x2 + -0.03670 * x1 ** 2 + 0.1632 * x2 **2 + 0.01521 * x1 * x2 +0.01288  * x5 + -0.1299 * x5**2 + -0.0278 * x2 * x5 )
    
    beta_3 = 3752.098 * (1 + 0.7636 * x1 + -0.4728 * x2  + 0.3576 * x2**2  + 0.5453 * x1**2 + 0.67459829 * x1 * x2 + -0.1017 * x5 + 0.1915  * x5**2 + 1.1921 * x2 * x5 + 0.72633366 * x1 * x5 + 0.01193 * x6 + 0.1114 * x6 **2 + -0.20152526  * x2 * x6 + 0.94373655 * x1 * x2 * x5 + 1.0158203 * x1 * x5 * x6 + -1.69506326 * x2 * x5 * x6 + 11.9561211 * x1 * x2 * x5 * x6)
    beta_4 = 407.009 *  (1 + 1.4784 * x1 + 0.2269 * x1 **2 + -0.066 * x2 + -0.1976 *x2**2 + -2.74281344 * x1 * x2 + 43.89663989 * x1 **2 * x2 **2 + 0.5307 * x5 + 0.1483 * x5**2 + 1.0168 * x2 * x5 +  5.56638597 * x1 * x5 + 1.3423 * x6 + 1.3534 * x6 **2 + 2.46017622 * x1 * x6 + 13.78584921 * x1 **2 * x6 **2  + -0.57399636 * x2 * x6 + 7.73679566 * x1 *  x2 * x5 + 0.67353606 * x1 * x5 * x6 + -1.21380304 * x2 * x5 * x6 + 37.99771398 * x1 * x2 * x5 * x6 + 43.14170145 * x1 * x2 * x5**2 * x6 )
    alpha =  2.5867 * (1 + -1.1877 * x1 + 0.700  * x2 +0.2784 * x1 **2  + 0.2064 * x2 **2 + -1.01633878 * x1 * x2 + -0.65334445 * x1 **2 * x2 **2 + 1.4088  * x5 + 0.7482    * x5**2  +1.006 *  x5 * x2 + -1.10231154 * x1 * x5 + -1.52840887 * x1 **2 * x5 **2+ 0.4324  * x6 +0.2114 * x6 **2 + 0.3 * x5 * x6  + 0.4246 * x2 * x6+ 0.0382146 * x1 * x6  + -0.14354912 * x2 * x6 + 0.37728709 * x1 * x2 * x5 + 0.60171565 * x1 * x5 * x6 + -0.20929162 * x2 * x5 * x6 + 2.06629063 * x1 * x2 * x5 * x6 + -0.45299093 * x1 * x2 * x5**2 * x6 + 6.09417101 * x1 **2 * x2 **2 * x6 **2 * x5 **2)
            
    sigm = (1 + np.exp(-(ell-beta_3)/beta_4))**(-1)

    poly = (beta_1*(ell/beta_2)**alpha - 1)
    
    L = poly*sigm + 1
    L[0:2000] = 1
    
    return L
